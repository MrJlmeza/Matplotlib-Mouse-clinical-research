# %%
#IMPORT DEPENDENCIES
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as sts

#FILES TO LOAD
mouse_metadata_path = "./data/Mouse_metadata.csv"
study_results_path = "./data/Study_results.csv"

#READ CSV FILES AS DATAFRAMES
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

#MERGE DATA FRAMES WITHOUT DUPLICATE MOUSE IDS
combined_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#CHECK THE NUMBER OF MICE
mice = combined_df["Mouse ID"].nunique()
mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint
duplicate_mice = combined_df.loc[combined_df.duplicated(subset=["Mouse ID", "Timepoint",]),"Mouse ID"].unique()
duplicate_mice_df = pd.DataFrame(duplicate_mice)
duplicate_mice_df
# Out:
#       0
# 0  g989

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
combined_clean_df = combined_df[combined_df['Mouse ID'].isin(duplicate_mice)==False]
combined_clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
 # Checking the number of mice in the clean DataFrame.
combined_clean_df["Mouse ID"].nunique()
# Out:
# 248

# %%
volMean = combined_clean_df.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
volMed = combined_clean_df.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
volStd = combined_clean_df.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
volVar = combined_clean_df.groupby('Drug Regimen').var()['Tumor Volume (mm3)']
volSem = combined_clean_df.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']
summ_stat_df = pd.DataFrame({"Mean": volMean, 
                             "Median": volMed,
                             "Var": volStd,
                             "std": volVar,
                             "sem": volSem})
summ_stat_df
# Out:
#                    Mean     Median       Var        std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  4.994774  24.947764  0.329346
# Ceftamin      52.591172  51.776157  6.268188  39.290177  0.469821
# Infubinol     52.884795  51.820584  6.567243  43.128684  0.492236
# Ketapril      55.235638  53.698743  8.279709  68.553577  0.603860
# Naftisol      54.331565  52.509285  8.134708  66.173479  0.596466
# Placebo       54.033581  52.288934  7.821003  61.168083  0.581331
# Propriva      52.320930  50.446266  6.622085  43.852013  0.544332
# Ramicane      40.216745  40.673236  4.846308  23.486704  0.320955
# Stelasyn      54.233149  52.431737  7.710419  59.450562  0.573111
# Zoniferol     53.236507  51.818479  6.966589  48.533355  0.516398

# %%
# Using the aggregation method, generate a summary statistics table in a single line for:
## [mean] [median] [variance] [standard deviation] [SEM]
drug_summary_df = combined_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem",],})
drug_summary_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
bar_data = combined_clean_df.groupby("Drug Regimen").nunique()["Mouse ID"]

pandasBar = bar_data.plot(kind="bar", title="Mice Count by Drug Regimen")
pandasBar.set_ylabel('Mice Count')
# Out:
# Text(0, 0.5, 'Mice Count')

# %%
#Create a bar plot for the number of mice on each regimen using pyplot
bar_data.plot.bar(legend=False)

plt.title("Mice Count by Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Mice Count")
# Out:
# Text(0, 0.5, 'Mice Count')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
genderPie = combined_clean_df["Sex"].value_counts()
explode = (0,0.1)
genderPie.plot(kind="pie", shadow=True, autopct="%1.2f%%", explode=explode, title="Gender of Mice")
# Out:
# <AxesSubplot:title={'center':'Gender of Mice'}, ylabel='Sex'>

# %%
plt.pie(genderPie, shadow=False, autopct="%1.2f%%", explode=explode, labels=("Male", "Female"))
plt.title("Gender of Mice")
plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
regimens_df = combined_clean_df.loc[combined_clean_df["Drug Regimen"].isin(regimens)]
# Start by getting the last (greatest) timepoint for each mouse
max_timepoint = regimens_df.groupby("Mouse ID")["Timepoint"].max()
# max_timepoint.columns = ["Timepoint"]

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
max_timepoint = max_timepoint.reset_index()
final_vol_df = pd.merge(max_timepoint, combined_clean_df, how="left", on=["Mouse ID", "Timepoint"])
final_vol_df
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a275         45     Ceftamin  Female          20          28
# 3      a411         45     Ramicane    Male           3          22
# 4      a444         45     Ramicane  Female          10          25
# ..      ...        ...          ...     ...         ...         ...
# 95     y769         45     Ceftamin  Female           6          27
# 96     y793         45    Capomulin    Male          17          17
# 97     y865         45     Ceftamin    Male          23          26
# 98     z578         45     Ramicane    Male          11          16
# 99     z581         45    Infubinol  Female          24          25
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            67.973419                 2
# 1            65.525743                 1
# ...

# %%
# Out:
# IQR for Capomulin: 22.742517952499995
# Lower Bound for Capomulin: 3.0739668737500097
# Upper Bound for Capomulin: 94.04403868374999
# IQR for Ramicane: 22.742517952499995
# Lower Bound for Ramicane: 3.0739668737500097
# Upper Bound for Ramicane: 94.04403868374999
# IQR for Infubinol: 22.742517952499995
# Lower Bound for Infubinol: 3.0739668737500097
# Upper Bound for Infubinol: 94.04403868374999
# IQR for Ceftamin: 22.742517952499995
# Lower Bound for Ceftamin: 3.0739668737500097
# Upper Bound for Ceftamin: 94.04403868374999
# IQR for Capomulin: 22.742517952499995
# Lower Bound for Capomulin: 3.0739668737500097
# Upper Bound for Capomulin: 94.04403868374999
# IQR for Ramicane: 22.742517952499995
# Lower Bound for Ramicane: 3.0739668737500097
# Upper Bound for Ramicane: 94.04403868374999
# IQR for Infubinol: 22.742517952499995
# Lower Bound for Infubinol: 3.0739668737500097
# Upper Bound for Infubinol: 94.04403868374999
# IQR for Ceftamin: 22.742517952499995
# ...
